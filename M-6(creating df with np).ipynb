# %%
#Creating Datasheet:
import numpy as np

data = np.array([
    [9.5, 0.5, 95.5],
    [8.5, 1.0, 90.0],
    [7.5, 1.5, 85.0],
    [6.5, 2.0, 80.0],
    [5.5, 2.5, 75.0],
    [4.5, 3.0, 70.0],
    [3.5, 3.5, 65.0],
    [2.5, 4.0, 55.0],
    [2.0, 4.2, 45.0],
    [1.5, 4.5, 39.5]
])

#print(data,"\n")
random_index=np.random.choice(10,size=(10,),replace=False)
data=data[random_index]
#print(data)
#Feature and Target col:
x=data[: ,0:2]  #by default 0 at ':'
#print(x)

y=data[: ,2:3]  
#print(y)

#Train, Test,Split:
train_index=int(len(data)*0.8)
x_train=x[0:train_index,:]
#print(x_train)

y_train=y[0:train_index,:]
#print(y_train)


x_test=x[train_index:,:]
print(x_test)

y_test=y[train_index:,:]
print(y_test)

#Another way and best way of Train, Test,data Split: just using the feature and target data
x=data[: ,0:2]  
y=data[: ,2:3]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(y_test)
